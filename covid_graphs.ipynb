# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 8C88-2027
#
#  Directory of C:\Desktop\git_workspace\covid-19-data
#
# 04/23/2020  02:12 PM    <DIR>          .
# 04/23/2020  02:12 PM    <DIR>          ..
# 04/23/2020  02:12 PM    <DIR>          .ipynb_checkpoints
# 04/23/2020  02:12 PM             1,311 LICENSE
# 04/23/2020  02:12 PM            13,562 README.md
# 04/23/2020  02:12 PM                72 Untitled.ipynb
# 04/23/2020  02:12 PM             1,877 us.csv
# 04/23/2020  02:12 PM         3,261,801 us-counties.csv
# 04/23/2020  02:12 PM            89,150 us-states.csv
#                6 File(s)      3,367,773 bytes
#                3 Dir(s)  292,776,718,336 bytes free

# %%
us_data = pd.read_csv("us.csv")
us_data.head()
# Out:
#          date  cases  deaths
# 0  2020-01-21      1       0
# 1  2020-01-22      1       0
# 2  2020-01-23      1       0
# 3  2020-01-24      2       0
# 4  2020-01-25      3       0

# %%
plt.plot(us_data['date'], us_data['cases'])
plt.plot(us_data['date'], us_data['deaths'])

# %%
us_data = pd.read_csv("us-states.csv")
us_data.head()
# Out:
#          date       state  fips  cases  deaths
# 0  2020-01-21  Washington    53      1       0
# 1  2020-01-22  Washington    53      1       0
# 2  2020-01-23  Washington    53      1       0
# 3  2020-01-24    Illinois    17      1       0
# 4  2020-01-24  Washington    53      1       0

# %%
states = [i for i in us_data['state'].unique()]
us_data[us_data['state'] == states[0]]
for i in states:
    data = 
    plt.plot(data['date'], data['cases'])
# Out:
#             date       state  fips  cases  deaths
# 0     2020-01-21  Washington    53      1       0
# 1     2020-01-22  Washington    53      1       0
# 2     2020-01-23  Washington    53      1       0
# 4     2020-01-24  Washington    53      1       0
# 7     2020-01-25  Washington    53      1       0
# 11    2020-01-26  Washington    53      1       0
# 15    2020-01-27  Washington    53      1       0
# 19    2020-01-28  Washington    53      1       0
# 23    2020-01-29  Washington    53      1       0
# 27    2020-01-30  Washington    53      1       0
# 31    2020-01-31  Washington    53      1       0
# 36    2020-02-01  Washington    53      1       0
# 41    2020-02-02  Washington    53      1       0
# 46    2020-02-03  Washington    53      1       0
# 51    2020-02-04  Washington    53      1       0
# 56    2020-02-05  Washington    53      1       0
# 62    2020-02-06  Washington    53      1       0
# 68    2020-02-07  Washington    53      1       0
# ...
